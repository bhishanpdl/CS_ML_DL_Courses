# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Moments:-Mean,-Variance,-Skew,-Kurtosis" data-toc-modified-id="Moments:-Mean,-Variance,-Skew,-Kurtosis-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Moments: Mean, Variance, Skew, Kurtosis</a></span><ul class="toc-item"><li><span><a href="#Activity" data-toc-modified-id="Activity-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Activity</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Moments: Mean, Variance, Skew, Kurtosis

# %% [markdown]
# Create a roughly normal-distributed random set of data:

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

vals = np.random.normal(0, 0.5, 10000)

plt.hist(vals, 50)
plt.show()

# %% [markdown]
# The first moment is the mean; this data should average out to about 0:

# %%
np.mean(vals)
# Out:
# 0.0030761613438204053

# %% [markdown]
# The second moment is the variance:

# %%
np.var(vals)
# Out:
# 0.24962106559173047

# %% [markdown]
# The third moment is skew - since our data is nicely centered around 0, it should be almost 0:

# %%
import scipy.stats as sp
sp.skew(vals)
# Out:
# -0.018249260513551597

# %% [markdown]
# The fourth moment is "kurtosis", which describes the shape of the tail. For a normal distribution, this is 0:

# %%
sp.kurtosis(vals)
# Out:
# 0.04795034855803815

# %% [markdown]
# ## Activity

# %% [markdown]
# Understanding skew: change the normal distribution to be centered around 10 instead of 0, and see what effect that has on the moments.
#
# The skew is still near zero; skew is associated with the shape of the distribution, not its actual offset in X.

# %%
from IPython.display import Image

# %%
Image('skew.png')

# %%
Image('kurtosis.png')
