# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Create-data" data-toc-modified-id="Create-data-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Create data</a></span></li><li><span><a href="#train-test-split" data-toc-modified-id="train-test-split-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>train test split</a></span></li><li><span><a href="#overfitting" data-toc-modified-id="overfitting-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>overfitting</a></span></li></ul></div>

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = [10, 8]
# %matplotlib inline

# %% [markdown]
# # Create data

# %%
np.random.seed(2)

pageSpeeds = np.random.normal(3.0, 1.0, 100)
purchaseAmount = np.random.normal(50.0, 30.0, 100) / pageSpeeds


plt.scatter(pageSpeeds, purchaseAmount)

# %% [markdown]
# # train test split

# %%
# data is already shuffled
# train to test 80 and 20 %
trainX = pageSpeeds[:80]
testX = pageSpeeds[80:]

trainY = purchaseAmount[:80]
testY = purchaseAmount[80:]

# %%
plt.scatter(trainX, trainY)

# %%
plt.scatter(testX, testY)

# %% [markdown]
# # overfitting
#
# Now we'll try to fit an 8th-degree polynomial to this data (which is almost certainly overfitting, given what we know about how it was generated!)

# %%
x = np.array(trainX)
y = np.array(trainY)

p4 = np.poly1d(np.polyfit(x, y, 8))

# %%
import matplotlib.pyplot as plt

xp = np.linspace(0, 7, 100)
axes = plt.axes()
axes.set_xlim([0,7])
axes.set_ylim([0, 200])
plt.scatter(x, y)
plt.plot(xp, p4(xp), c='r')
plt.show()

# %%
# And against our test data:

# %%
testx = np.array(testX)
testy = np.array(testY)

axes = plt.axes()
axes.set_xlim([0,7])
axes.set_ylim([0, 200])
plt.scatter(testx, testy)
plt.plot(xp, p4(xp), c='r')
plt.show()

# %% [markdown]
# Doesn't look that bad when you just eyeball it, but the r-squared score on the test data is kind of horrible! This tells us that our model isn't all that great...

# %%
from sklearn.metrics import r2_score

r2 = r2_score(testy, p4(testx))

print(r2)
# Out:
# 0.30018168611266705

# %%
# ...even though it fits the training data better:

# %%
from sklearn.metrics import r2_score

r2 = r2_score(np.array(trainY), p4(np.array(trainX)))

print(r2)
# Out:
# 0.6427069514690176
