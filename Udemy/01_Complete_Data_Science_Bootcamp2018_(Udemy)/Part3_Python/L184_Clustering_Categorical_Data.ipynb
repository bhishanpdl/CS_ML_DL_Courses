# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Clustering-Categorical-Data" data-toc-modified-id="Clustering-Categorical-Data-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Clustering Categorical Data</a></span><ul class="toc-item"><li><span><a href="#Import-the-relevant-libraries" data-toc-modified-id="Import-the-relevant-libraries-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Import the relevant libraries</a></span></li><li><span><a href="#Load-the-data" data-toc-modified-id="Load-the-data-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Load the data</a></span></li><li><span><a href="#Map-the-data" data-toc-modified-id="Map-the-data-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Map the data</a></span></li><li><span><a href="#Select-the-features" data-toc-modified-id="Select-the-features-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Select the features</a></span></li><li><span><a href="#Clustering" data-toc-modified-id="Clustering-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Clustering</a></span></li><li><span><a href="#Clustering-results" data-toc-modified-id="Clustering-results-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Clustering results</a></span></li><li><span><a href="#Plot-the-data" data-toc-modified-id="Plot-the-data-1.7"><span class="toc-item-num">1.7&nbsp;&nbsp;</span>Plot the data</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Clustering Categorical Data

# %% [markdown]
# You are given much more country data. Using the same methodology as the one in the lecture, group all the countries in 2 clusters.
#
# <b> Already done that? Okay! </b>
#
# There are other features: name and continent.
#
# Encode the continent one and use it in the clustering solution. Think about the difference with the previous exercise.

# %% [markdown]
# ## Import the relevant libraries

# %%
import numpy as np
import pandas as pd
import scipy
import statsmodels.api as sm
import sklearn

# plotting
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set(color_codes=True)
sns.set()

# seaborn warnings ignore
import warnings
warnings.filterwarnings('ignore')

# Jupyter notebook settings for pandas
pd.set_option('display.float_format', '{:,.2f}'.format) # numbers sep by comma
pd.set_option('display.max_rows', 100) # None for all the rows
pd.set_option('display.max_colwidth', 100)

# ipython
from IPython.display import Image

# %%
from sklearn.cluster import KMeans

# %% [markdown]
# ## Load the data

# %% [markdown]
# Load data from the csv file: <i> 'Categorical.csv'</i>.

# %%
# !ls ../data/csv
# Out:
# Bank-data-testing.csv                Countries-exercise.csv               real_estate_price_size_year.csv
# Bank-data.csv                        Example-bank-data.csv                real_estate_price_size_year_view.csv
# Categorical.csv                      real_estate_price_size.csv

# %% [markdown]
# Remove the duplicate index column from the dataset.

# %%
df = pd.read_csv('../data/csv/Categorical.csv')
print(df.shape)
df.head()
# Out:
# (241, 4)
#           name  Longitude  Latitude      continent
# 0        Aruba     -69.98     12.52  North America
# 1  Afghanistan      66.00     33.84           Asia
# 2       Angola      17.54    -12.29         Africa
# 3     Anguilla     -63.06     18.22  North America
# 4      Albania      20.05     41.14         Europe

# %% [markdown]
# ## Map the data

# %% [markdown]
# Use the <i>'continent'</i> category for this analysis.

# %%
df['continent'].unique()
# Out:
# array(['North America', 'Asia', 'Africa', 'Europe', 'South America',
#        'Oceania', 'Antarctica', 'Seven seas (open ocean)'], dtype=object)

# %%
df['continent_cat'] = df['continent'].map({'North America':0,'Europe':1,'Asia':2,'Africa':3,'South America':4, 'Oceania':5,'Seven seas (open ocean)':6, 'Antarctica':7})

# df['continent_cat'] = df['continent'].astype('category').cat.codes


df.head()
# Out:
#           name  Longitude  Latitude      continent  continent_cat
# 0        Aruba     -69.98     12.52  North America              0
# 1  Afghanistan      66.00     33.84           Asia              2
# 2       Angola      17.54    -12.29         Africa              3
# 3     Anguilla     -63.06     18.22  North America              0
# 4      Albania      20.05     41.14         Europe              1

# %% [markdown]
# ## Select the features

# %%
x = df.iloc[:,4:5].copy()
x.head()
# Out:
#    continent_cat
# 0              0
# 1              2
# 2              3
# 3              0
# 4              1

# %% [markdown]
# ## Clustering

# %% [markdown]
# Use 4 clusters initially.

# %%
x = x.values.reshape(-1,1)
kmeans = KMeans(n_clusters=4,random_state=100)
kmeans.fit(x)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=4, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=100, tol=0.0001, verbose=0)

# %% [markdown]
# ## Clustering results

# %%
pred = kmeans.fit_predict(x)
pred[0:5]
# Out:
# array([1, 2, 0, 1, 1], dtype=int32)

# %%
df['Cluster'] = pred
df.head()
# Out:
#           name  Longitude  Latitude      continent  continent_cat  Cluster
# 0        Aruba     -69.98     12.52  North America              0        1
# 1  Afghanistan      66.00     33.84           Asia              2        2
# 2       Angola      17.54    -12.29         Africa              3        0
# 3     Anguilla     -63.06     18.22  North America              0        1
# 4      Albania      20.05     41.14         Europe              1        1

# %% [markdown]
# ## Plot the data

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12,8), sharey=True )
sns.scatterplot(data=df, x='Longitude',y='Latitude',hue='Cluster',cmap='Paired',ax=ax1)
sns.scatterplot(data=df, x='Longitude',y='Latitude',hue='continent_cat',cmap='Paired',ax=ax2)

# %%
plt.scatter(df['Longitude'], df['Latitude'], c=df['Cluster'], cmap = 'rainbow')
plt.xlim(-180,180)
plt.ylim(-90, 90)
plt.show()

# %%
df.plot(kind='scatter',x='Longitude',y='Latitude',c='Cluster',cmap='rainbow')

# %% [markdown]
# Since you already have all the code necessary, go back and play around with the number of clusters. Try 3, 7 and 8 and see if the results match your expectations.

# %% [markdown]
# Simply go back to the beggining of the <b> Clustering </b> section and change <i> kmeans = KMeans(4) </i> to <i> kmeans = KMeans(3) </i>. Then run the remaining cells until the end.

# %%
df.head()
# Out:
#           name  Longitude  Latitude      continent  continent_cat  Cluster
# 0        Aruba     -69.98     12.52  North America              0        1
# 1  Afghanistan      66.00     33.84           Asia              2        2
# 2       Angola      17.54    -12.29         Africa              3        0
# 3     Anguilla     -63.06     18.22  North America              0        1
# 4      Albania      20.05     41.14         Europe              1        1

# %%
df2 = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/2014_world_gdp_with_codes.csv')
print(df2.head())
# Out:
#           COUNTRY  GDP (BILLIONS) CODE
# 0     Afghanistan           21.71  AFG
# 1         Albania           13.40  ALB
# 2         Algeria          227.80  DZA
# 3  American Samoa            0.75  ASM
# 4         Andorra            4.80  AND

# %%
df = pd.merge(df, df2, how='left', left_on='name', right_on='COUNTRY')
df.head()
# Out:
#           name  Longitude  Latitude      continent  continent_cat  Cluster  \
# 0        Aruba     -69.98     12.52  North America              0        1
# 1  Afghanistan      66.00     33.84           Asia              2        2
# 2       Angola      17.54    -12.29         Africa              3        0
# 3     Anguilla     -63.06     18.22  North America              0        1
# 4      Albania      20.05     41.14         Europe              1        1
#
#        COUNTRY  GDP (BILLIONS) CODE
# 0        Aruba            2.52  ABW
# 1  Afghanistan           21.71  AFG
# 2       Angola          131.40  AGO
# 3     Anguilla            0.18  AIA
# 4      Albania           13.40  ALB

# %%
df[df['CODE'].isnull()]
# Out:
#                           name  Longitude  Latitude                continent  \
# 5                        Aland      19.95     60.21                   Europe
# 11                  Antarctica      19.92    -80.51               Antarctica
# 12     Ashmore and Cartier Is.     123.58    -12.43                  Oceania
# 13      Fr. S. Antarctic Lands      69.23    -49.25  Seven seas (open ocean)
# 14           Antigua and Barb.     -61.79     17.28            North America
# 26                     Bahamas     -76.63     24.29            North America
# 27            Bosnia and Herz.      17.77     44.17                   Europe
# 28              St-Barth̩lemy     -62.84     17.90            North America
# 38        Central African Rep.      20.47      6.57                   Africa
# 42              C̫te d'Ivoire      -5.57      7.63                   Africa
# 44             Dem. Rep. Congo      23.64     -2.88                   Africa
# 45                       Congo      15.22     -0.84                   Africa
# 46                    Cook Is.    -159.79    -21.22                  Oceania
# 49                  Cape Verde     -23.96     15.96                   Africa
# 52                    Cura̤ao     -68.97     12.20            North America
# 53                  Cayman Is.     -80.91     19.43            North America
# 54                   N. Cyprus      33.57     35.26                     Asia
# 56                  Czech Rep.      15.31     49.73                   Europe
# 61              Dominican Rep.     -70.51     18.89            North America
# 71                Falkland Is.     -59.35    -51.74            South America
# 73                  Faeroe Is.      -6.88     62.05                   Europe
# 74                  Micronesia     153.24      7.45                  Oceania
# 81                      Gambia     -15.40     13.45                   Africa
# 83                  Eq. Guinea      10.34      1.71                   Africa
# 91   Heard I. and McDonald Is.      73.52    -53.09  Seven seas (open ocean)
# 99           Indian Ocean Ter.     104.85    -10.65                     Asia
# 100      Br. Indian Ocean Ter.      72.45     -7.33  Seven seas (open ocean)
# 111            Siachen Glacier      77.18     35.39                     Asia
# 117        St. Kitts and Nevis     -62.69     17.26            North America
# 118                      Korea     127.84     36.39                     Asia
# 121                    Lao PDR     103.74     18.50                     Asia
# 132                      Macao     113.51     22.22                     Asia
# 133                  St-Martin     -63.06     18.09            North America
# 140               Marshall Is.     170.34      7.00                  Oceania
# 144                    Myanmar      96.49     21.19                     Asia
# 147             N. Mariana Is.     145.62     15.83                  Oceania
# 150                 Montserrat     -62.19     16.74            North America
# 157             Norfolk Island     167.95    -29.05                  Oceania
# 164                      Nauru     166.93     -0.52                  Oceania
# 169               Pitcairn Is.    -128.32    -24.37                  Oceania
# 176            Dem. Rep. Korea     127.19     40.15                     Asia
# 179                  Palestine      35.20     31.92                     Asia
# 180              Fr. Polynesia    -144.90    -14.72                  Oceania
# 185                  W. Sahara     -12.22     24.23                   Africa
# 188                   S. Sudan      30.25      7.31                   Africa
# 191  S. Geo. and S. Sandw. Is.     -36.43    -54.46  Seven seas (open ocean)
# 192               Saint Helena      -9.55    -12.40  Seven seas (open ocean)
# 193                Solomon Is.     159.63     -8.92                  Oceania
# 197                 Somaliland      46.25      9.73                   Africa
# 199    St. Pierre and Miquelon     -56.30     46.92            North America
# 201    Ṣo Tom̩ and Principe       6.72      0.44                   Africa
# 210       Turks and Caicos Is.     -71.97     21.83            North America
# 228                    Vatican      12.43     41.90                   Europe
# 229         St. Vin. and Gren.     -61.20     13.22            North America
# 231         British Virgin Is.     -64.47     18.53            North America
# 232            U.S. Virgin Is.     -64.80     17.96            North America
# 235      Wallis and Futuna Is.    -177.35    -13.89                  Oceania
#
#      continent_cat  Cluster COUNTRY  GDP (BILLIONS) CODE
# 5                1        1     NaN             nan  NaN
# 11               7        3     NaN             nan  NaN
# 12               5        3     NaN             nan  NaN
# 13               6        3     NaN             nan  NaN
# 14               0        1     NaN             nan  NaN
# 26               0        1     NaN             nan  NaN
# 27               1        1     NaN             nan  NaN
# 28               0        1     NaN             nan  NaN
# 38               3        0     NaN             nan  NaN
# 42               3        0     NaN             nan  NaN
# 44               3        0     NaN             nan  NaN
# 45               3        0     NaN             nan  NaN
# 46               5        3     NaN             nan  NaN
# 49               3        0     NaN             nan  NaN
# 52               0        1     NaN             nan  NaN
# 53               0        1     NaN             nan  NaN
# 54               2        2     NaN             nan  NaN
# 56               1        1     NaN             nan  NaN
# 61               0        1     NaN             nan  NaN
# 71               4        0     NaN             nan  NaN
# 73               1        1     NaN             nan  NaN
# 74               5        3     NaN             nan  NaN
# 81               3        0     NaN             nan  NaN
# 83               3        0     NaN             nan  NaN
# 91               6        3     NaN             nan  NaN
# 99               2        2     NaN             nan  NaN
# 100              6        3     NaN             nan  NaN
# 111              2        2     NaN             nan  NaN
# 117              0        1     NaN             nan  NaN
# 118              2        2     NaN             nan  NaN
# 121              2        2     NaN             nan  NaN
# 132              2        2     NaN             nan  NaN
# 133              0        1     NaN             nan  NaN
# 140              5        3     NaN             nan  NaN
# 144              2        2     NaN             nan  NaN
# 147              5        3     NaN             nan  NaN
# 150              0        1     NaN             nan  NaN
# 157              5        3     NaN             nan  NaN
# 164              5        3     NaN             nan  NaN
# 169              5        3     NaN             nan  NaN
# 176              2        2     NaN             nan  NaN
# 179              2        2     NaN             nan  NaN
# 180              5        3     NaN             nan  NaN
# 185              3        0     NaN             nan  NaN
# 188              3        0     NaN             nan  NaN
# 191              6        3     NaN             nan  NaN
# 192              6        3     NaN             nan  NaN
# 193              5        3     NaN             nan  NaN
# 197              3        0     NaN             nan  NaN
# 199              0        1     NaN             nan  NaN
# 201              3        0     NaN             nan  NaN
# 210              0        1     NaN             nan  NaN
# 228              1        1     NaN             nan  NaN
# 229              0        1     NaN             nan  NaN
# 231              0        1     NaN             nan  NaN
# 232              0        1     NaN             nan  NaN
# 235              5        3     NaN             nan  NaN

# %%
df.head()
# Out:
#           name  Longitude  Latitude      continent  continent_cat  Cluster  \
# 0        Aruba     -69.98     12.52  North America              0        1
# 1  Afghanistan      66.00     33.84           Asia              2        2
# 2       Angola      17.54    -12.29         Africa              3        0
# 3     Anguilla     -63.06     18.22  North America              0        1
# 4      Albania      20.05     41.14         Europe              1        1
#
#        COUNTRY  GDP (BILLIONS) CODE
# 0        Aruba            2.52  ABW
# 1  Afghanistan           21.71  AFG
# 2       Angola          131.40  AGO
# 3     Anguilla            0.18  AIA
# 4      Albania           13.40  ALB

# %%
import plotly.plotly as py
import pandas as pd

# df = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/2014_world_gdp_with_codes.csv')

data = [ dict(
        type = 'choropleth',
        locations = df['CODE'],
        z = df['Cluster'],
        text = df['name'],
        autocolorscale= True,
        reversescale = True,
        marker = dict(
            line = dict (
                color = 'rgb(180,180,180)',
                width = 0.5
            ) ),
        colorbar = dict(
            autotick = False,
            tickprefix = '',
            title = 'Continent'),
      ) ]

layout = dict(
    title = 'Country',
    geo = dict(
        showframe = False,
        showcoastlines = False,
        projection = dict(
            type = 'Mercator'
        )
    )
)

fig = dict( data=data, layout=layout )
py.iplot( fig, validate=False, filename='d3-world-map' )
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~bhishanpdl/44.embed" height="525px" width="100%"></iframe>

# %%
Image(filename=('../data/snapshots/cluster_country_map.png'),width=1000)
